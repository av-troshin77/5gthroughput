# %% [markdown]
# # Multivariate CNN-LSTM

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
# fix tensorflow gpu problems
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
# check gpu support
gpus = tf.config.list_physical_devices('GPU')
print(len(gpus))
print(tf.test.is_built_with_gpu_support())
print(tf.test.is_built_with_cuda())
print(tf.test.gpu_device_name())
# Out:
# 0
# True
# True

# %% [markdown]
# ## 1. Load the Dataset

# %%
df = pd.read_csv('Lumos5G-v1.0.csv', 
                index_col=['run_num', 'seq_num'])
df.head(5)
# Out:
#                  abstractSignalStr   latitude  longitude  movingSpeed  \
# run_num seq_num
# 1       1.0                      2  44.975314 -93.259316     0.094889
#         2.0                      2  44.975311 -93.259311     0.876634
#         3.0                      2  44.975305 -93.259292     2.225798
#         4.0                      2  44.975293 -93.259258     3.180726
#         5.0                      2  44.975278 -93.259214     3.751234
#
#                  compassDirection        nrStatus  lte_rssi  lte_rsrp  \
# run_num seq_num
# 1       1.0                   150  NOT_RESTRICTED     -61.0       -94
#         2.0                   117  NOT_RESTRICTED     -61.0       -94
#         3.0                   113  NOT_RESTRICTED     -61.0       -94
#         4.0                   114  NOT_RESTRICTED     -59.0       -95
#         5.0                   115  NOT_RESTRICTED     -59.0       -95
#
#                  lte_rsrq     lte_rssnr  nr_ssRsrp  nr_ssRsrq  nr_ssSinr  \
# run_num seq_num
# 1       1.0         -14.0  2.147484e+09        NaN        NaN        NaN
#         2.0         -14.0  2.147484e+09        NaN        NaN        NaN
#         3.0         -14.0  2.147484e+09        NaN        NaN        NaN
#         4.0         -16.0  2.147484e+09        NaN        NaN        NaN
#         5.0         -16.0  2.147484e+09        NaN        NaN        NaN
#
#                  Throughput mobility_mode trajectory_direction  tower_id
# run_num seq_num
# 1       1.0              78       driving                   CW        16
#         2.0             117       driving                   CW        16
#         3.0             110       driving                   CW        16
#         4.0             108       driving                   CW        16
#         5.0             100       driving                   CW        16

# %%
# select columns
ndf = df[["latitude",
          "longitude",
          "abstractSignalStr",
          "movingSpeed",
          "compassDirection",
          "lte_rssi",
          "lte_rsrp",
          "lte_rsrq",
          "tower_id",
          "lte_rssnr",
          "Throughput"]]
ndf.head()
# Out:
#                   latitude  longitude  abstractSignalStr  movingSpeed  \
# run_num seq_num
# 1       1.0      44.975314 -93.259316                  2     0.094889
#         2.0      44.975311 -93.259311                  2     0.876634
#         3.0      44.975305 -93.259292                  2     2.225798
#         4.0      44.975293 -93.259258                  2     3.180726
#         5.0      44.975278 -93.259214                  2     3.751234
#
#                  compassDirection  lte_rssi  lte_rsrp  lte_rsrq  tower_id  \
# run_num seq_num
# 1       1.0                   150     -61.0       -94     -14.0        16
#         2.0                   117     -61.0       -94     -14.0        16
#         3.0                   113     -61.0       -94     -14.0        16
#         4.0                   114     -59.0       -95     -16.0        16
#         5.0                   115     -59.0       -95     -16.0        16
#
#                     lte_rssnr  Throughput
# run_num seq_num
# 1       1.0      2.147484e+09          78
#         2.0      2.147484e+09         117
#         3.0      2.147484e+09         110
#         4.0      2.147484e+09         108
#         5.0      2.147484e+09         100

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 68118 entries, (1, 1.0) to (118, 783.0)
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   latitude           68118 non-null  float64
#  1   longitude          68118 non-null  float64
#  2   abstractSignalStr  68118 non-null  int64
#  3   movingSpeed        68118 non-null  float64
#  4   compassDirection   68118 non-null  int64
#  5   lte_rssi           65137 non-null  float64
#  6   lte_rsrp           68118 non-null  int64
#  7   lte_rsrq           65137 non-null  float64
#  8   tower_id           68118 non-null  int64
#  9   lte_rssnr          65137 non-null  float64
#  10  Throughput         68118 non-null  int64
# dtypes: float64(6), int64(5)
# memory usage: 5.9 MB

# %%
# fill nans with zeros
ndf = ndf.fillna(0)
ndf.isna().sum().sum() # check nans
# Out:
# 0

# %%
max_throughput = ndf["Throughput"].max()
min_throughput = ndf["Throughput"].min()
print(f'Max throughput: {max_throughput}')
print(f'Min throughput: {min_throughput}')
max_throughput = max_throughput.item() # get python int
# Out:
# Max throughput: 1920
# Min throughput: 0

# %%
# Min-Max Scaling
df=(ndf-ndf.min())/(ndf.max()-ndf.min())
df.head()
# Out:
#                  latitude  longitude  abstractSignalStr  movingSpeed  \
# run_num seq_num
# 1       1.0      0.555052   0.931652               0.25     0.006749
#         2.0      0.554351   0.932764               0.25     0.062350
#         3.0      0.552584   0.936669               0.25     0.158308
#         4.0      0.549415   0.943976               0.25     0.226227
#         5.0      0.545235   0.953213               0.25     0.266804
#
#                  compassDirection  lte_rssi  lte_rsrp  lte_rsrq  tower_id  \
# run_num seq_num
# 1       1.0              0.416667  0.227848  0.479167       0.3  0.652174
#         2.0              0.325000  0.227848  0.479167       0.3  0.652174
#         3.0              0.313889  0.227848  0.479167       0.3  0.652174
#         4.0              0.316667  0.253165  0.468750       0.2  0.652174
#         5.0              0.319444  0.253165  0.468750       0.2  0.652174
#
#                  lte_rssnr  Throughput
# run_num seq_num
# 1       1.0            1.0    0.040625
#         2.0            1.0    0.060937
#         3.0            1.0    0.057292
#         4.0            1.0    0.056250
#         5.0            1.0    0.052083

# %% [markdown]
# ## 2. Create Train-Test Sets

# %%
# split function into sequences
# y data from the last column 
def multistep_split(seq, n_steps_in, n_steps_out):
    X = list()
    y = list()
    for i in range(len(seq)):
        # pattern end
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        if out_end_ix > len(seq):
            break
        seq_x = seq[i:end_ix]
        seq_y = seq[end_ix:out_end_ix, -1]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# separately splits runs into sequences
run_max=df.index.max()[0]
seconds_in = 20
seconds_out = 20 
X_list = list()
y_list = list()
for run_num in range(1, run_max+1):
    run = df.loc[run_num].values
    X, y = multistep_split(run.astype('float32'), n_steps_in=seconds_in, n_steps_out=seconds_out)
    X_list.append(X)
    y_list.append(y)
X = np.concatenate(X_list)
y = np.concatenate(y_list)
print(X.shape)
print(y.shape)
# Out:
# (63516, 20, 11)
# (63516, 20)

# %%
ratio=0.7
train_size = int(ratio*X.shape[0])
X_train = X[:train_size]
y_train = y[:train_size]
X_test = X[train_size:]
y_test = y[train_size:]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (44461, 20, 11)
# (44461, 20)
# (19055, 20, 11)
# (19055, 20)

# %% [markdown]
# ## 3. Multivarate CNN-LSTM

# %%
n_features = X_train.shape[2]
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv1D(filters=32,
                                 kernel_size=4,
                                 activation='relu',
                                 input_shape=(seconds_in, n_features)))
model.add(tf.keras.layers.Conv1D(filters=16,
                                 kernel_size=2,
                                 activation='relu'))
model.add(tf.keras.layers.MaxPool1D(pool_size=2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.RepeatVector(seconds_out))
model.add(tf.keras.layers.LSTM(32, activation='tanh',
                               return_sequences=True))
model.add(tf.keras.layers.TimeDistributed(
          tf.keras.layers.Dense(16, activation='relu')))
model.add(tf.keras.layers.TimeDistributed(
          tf.keras.layers.Dense(1, activation='linear')))     
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 17, 32)            1440
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 16, 16)            1040
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 8, 16)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 20, 128)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 20, 32)            20608
# _________________________________________________________________
# time_distributed (TimeDistri (None, 20, 16)            528
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 20, 1)             17
# =================================================================
# Total params: 23,633
# Trainable params: 23,633
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
             loss='mean_squared_error')

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                  min_delta=0.0001,
                                                  patience=10,
                                                  verbose=0,
                                                  mode='auto',
                                                  restore_best_weights=True)

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=50,
                    batch_size=16,
                    validation_data=(X_test, y_test),
                    callbacks=[early_stopping],
                    verbose=1)
# Out:
# Epoch 1/50
# 2779/2779 [==============================] - 29s 10ms/step - loss: 0.0415 - val_loss: 0.0337
# Epoch 2/50
# 2779/2779 [==============================] - 27s 10ms/step - loss: 0.0350 - val_loss: 0.0329
# Epoch 3/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0330 - val_loss: 0.0326
# Epoch 4/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0318 - val_loss: 0.0329
# Epoch 5/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0305 - val_loss: 0.0326
# Epoch 6/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0296 - val_loss: 0.0346
# Epoch 7/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0290 - val_loss: 0.0341
# Epoch 8/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0280 - val_loss: 0.0326
# Epoch 9/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0276 - val_loss: 0.0324
# Epoch 10/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0267 - val_loss: 0.0333
# Epoch 11/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0261 - val_loss: 0.0324
# Epoch 12/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0256 - val_loss: 0.0328
# Epoch 13/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0252 - val_loss: 0.0328
# Epoch 14/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0247 - val_loss: 0.0334
# Epoch 15/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0245 - val_loss: 0.0327
# Epoch 16/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0240 - val_loss: 0.0332
# Epoch 17/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0237 - val_loss: 0.0334
# Epoch 18/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0234 - val_loss: 0.0341
# Epoch 19/50
# 2779/2779 [==============================] - 26s 9ms/step - loss: 0.0231 - val_loss: 0.0332

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
min_mse = min(val_loss)
print(f'Minimal Loss: {min_mse:.4f}')
print(f'RMSE: {np.sqrt(min_mse)*max_throughput}')
plt.figure(figsize=(10,5))
plt.plot(loss, 'r', label='Loss of training data')
plt.plot(val_loss, 'b-', label='Loss of validation data')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Training Epoch')
plt.legend()
plt.show()
# Out:
# Minimal Loss: 0.0324
# RMSE: 345.44201606406006

# %%
n = 60 # example number
y_true = y_test[n]
x_in = X_test[n].reshape((1, seconds_in, 1))
y_pred = model.predict(x_in).flatten()
plt.plot(y_true*max_throughput, 'b')
plt.plot(y_pred*max_throughput, 'r')
plt.ylim(0, max_throughput)
print(f'Forecast MSE of the example: {mean_squared_error(y_true, y_pred):.4f}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-ec9ea89c79cf> in <module>
#       1 n = 60 # example number
#       2 y_true = y_test[n]
# ----> 3 x_in = X_test[n].reshape((1, seconds_in, 1))
#       4 y_pred = model.predict(x_in).flatten()
#       5 plt.plot(y_true*max_throughput, 'b')
#
# ValueError: cannot reshape array of size 220 into shape (1,20,1)
