# %% [markdown]
# # Multivariate CNN-LSTM

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
# fix tensorflow gpu problems
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
# check gpu support
gpus = tf.config.list_physical_devices('GPU')
print(len(gpus))
print(tf.test.is_built_with_gpu_support())
print(tf.test.is_built_with_cuda())
print(tf.test.gpu_device_name())
# Out:
# 1
# True
# True
# /device:GPU:0

# %% [markdown]
# ## 1. Load the Dataset

# %%
df = pd.read_csv('Lumos5G-v1.0.csv', 
                index_col=['run_num', 'seq_num'])
df.head(5)
# Out:
#                  abstractSignalStr   latitude  longitude  movingSpeed  \
# run_num seq_num
# 1       1.0                      2  44.975314 -93.259316     0.094889
#         2.0                      2  44.975311 -93.259311     0.876634
#         3.0                      2  44.975305 -93.259292     2.225798
#         4.0                      2  44.975293 -93.259258     3.180726
#         5.0                      2  44.975278 -93.259214     3.751234
#
#                  compassDirection        nrStatus  lte_rssi  lte_rsrp  \
# run_num seq_num
# 1       1.0                   150  NOT_RESTRICTED     -61.0       -94
#         2.0                   117  NOT_RESTRICTED     -61.0       -94
#         3.0                   113  NOT_RESTRICTED     -61.0       -94
#         4.0                   114  NOT_RESTRICTED     -59.0       -95
#         5.0                   115  NOT_RESTRICTED     -59.0       -95
#
#                  lte_rsrq     lte_rssnr  nr_ssRsrp  nr_ssRsrq  nr_ssSinr  \
# run_num seq_num
# 1       1.0         -14.0  2.147484e+09        NaN        NaN        NaN
#         2.0         -14.0  2.147484e+09        NaN        NaN        NaN
#         3.0         -14.0  2.147484e+09        NaN        NaN        NaN
#         4.0         -16.0  2.147484e+09        NaN        NaN        NaN
#         5.0         -16.0  2.147484e+09        NaN        NaN        NaN
#
#                  Throughput mobility_mode trajectory_direction  tower_id
# run_num seq_num
# 1       1.0              78       driving                   CW        16
#         2.0             117       driving                   CW        16
#         3.0             110       driving                   CW        16
#         4.0             108       driving                   CW        16
#         5.0             100       driving                   CW        16

# %%
# select columns
df = df[["latitude",
          "longitude",
          "abstractSignalStr",
          "movingSpeed",
          "compassDirection",
          "lte_rssi",
          "lte_rsrp",
          "lte_rsrq",
          "tower_id",
          "lte_rssnr",
          "Throughput"]]
df.head()
# Out:
#                   latitude  longitude  abstractSignalStr  movingSpeed  \
# run_num seq_num
# 1       1.0      44.975314 -93.259316                  2     0.094889
#         2.0      44.975311 -93.259311                  2     0.876634
#         3.0      44.975305 -93.259292                  2     2.225798
#         4.0      44.975293 -93.259258                  2     3.180726
#         5.0      44.975278 -93.259214                  2     3.751234
#
#                  compassDirection  lte_rssi  lte_rsrp  lte_rsrq  tower_id  \
# run_num seq_num
# 1       1.0                   150     -61.0       -94     -14.0        16
#         2.0                   117     -61.0       -94     -14.0        16
#         3.0                   113     -61.0       -94     -14.0        16
#         4.0                   114     -59.0       -95     -16.0        16
#         5.0                   115     -59.0       -95     -16.0        16
#
#                     lte_rssnr  Throughput
# run_num seq_num
# 1       1.0      2.147484e+09          78
#         2.0      2.147484e+09         117
#         3.0      2.147484e+09         110
#         4.0      2.147484e+09         108
#         5.0      2.147484e+09         100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 68118 entries, (1, 1.0) to (118, 783.0)
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   latitude           68118 non-null  float64
#  1   longitude          68118 non-null  float64
#  2   abstractSignalStr  68118 non-null  int64
#  3   movingSpeed        68118 non-null  float64
#  4   compassDirection   68118 non-null  int64
#  5   lte_rssi           65137 non-null  float64
#  6   lte_rsrp           68118 non-null  int64
#  7   lte_rsrq           65137 non-null  float64
#  8   tower_id           68118 non-null  int64
#  9   lte_rssnr          65137 non-null  float64
#  10  Throughput         68118 non-null  int64
# dtypes: float64(6), int64(5)
# memory usage: 6.0 MB

# %%
# fill nans with zeros
df = df.fillna(0)
df.isna().sum().sum() # check nans
# Out:
# 0

# %%
max_throughput = df["Throughput"].max()
min_throughput = df["Throughput"].min()
print(f'Max throughput: {max_throughput}')
print(f'Min throughput: {min_throughput}')
max_throughput = max_throughput.item() # get python int
# Out:
# Max throughput: 1920
# Min throughput: 0

# %%
# Min-Max Scaling
df=(df-df.min())/(df.max()-df.min())
df.head()
# Out:
#                  latitude  longitude  abstractSignalStr  movingSpeed  \
# run_num seq_num
# 1       1.0      0.555052   0.931652               0.25     0.006749
#         2.0      0.554351   0.932764               0.25     0.062350
#         3.0      0.552584   0.936669               0.25     0.158308
#         4.0      0.549415   0.943976               0.25     0.226227
#         5.0      0.545235   0.953213               0.25     0.266804
#
#                  compassDirection  lte_rssi  lte_rsrp  lte_rsrq  tower_id  \
# run_num seq_num
# 1       1.0              0.416667  0.227848  0.479167       0.3  0.652174
#         2.0              0.325000  0.227848  0.479167       0.3  0.652174
#         3.0              0.313889  0.227848  0.479167       0.3  0.652174
#         4.0              0.316667  0.253165  0.468750       0.2  0.652174
#         5.0              0.319444  0.253165  0.468750       0.2  0.652174
#
#                  lte_rssnr  Throughput
# run_num seq_num
# 1       1.0            1.0    0.040625
#         2.0            1.0    0.060937
#         3.0            1.0    0.057292
#         4.0            1.0    0.056250
#         5.0            1.0    0.052083

# %% [markdown]
# ## 2. Create Train-Test Sets

# %%
# split function into sequences
# y data from the last column 
def multistep_split(seq, n_steps_in, n_steps_out):
    X = list()
    y = list()
    for i in range(len(seq)):
        # pattern end
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        if out_end_ix > len(seq):
            break
        seq_x = seq[i:end_ix]
        seq_y = seq[end_ix:out_end_ix, -1]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# separately splits runs into sequences
run_max=df.index.max()[0]
seconds_in = 20
seconds_out = 20 
X_list = list()
y_list = list()
for run_num in range(1, run_max+1):
    run = df.loc[run_num].values
    X, y = multistep_split(run.astype('float32'), n_steps_in=seconds_in, n_steps_out=seconds_out)
    X_list.append(X)
    y_list.append(y)
X = np.concatenate(X_list)
y = np.concatenate(y_list)
print(X.shape)
print(y.shape)
# Out:
# (63516, 20, 11)
# (63516, 20)

# %%
ratio=0.7
train_size = int(ratio*X.shape[0])
X_train = X[:train_size]
y_train = y[:train_size]
X_test = X[train_size:]
y_test = y[train_size:]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (44461, 20, 11)
# (44461, 20)
# (19055, 20, 11)
# (19055, 20)

# %% [markdown]
# ## 3. Multivarate CNN-LSTM

# %%
def cnn_lstm(seconds_in, seconds_out, n_features, lr=0.0001):
    # define layers
    inputs = tf.keras.Input(shape=(seconds_in, n_features))
    conv1 = tf.keras.layers.Conv1D(filters=64, kernel_size=4, activation='relu')
    conv2 = tf.keras.layers.Conv1D(filters=32, kernel_size=4, activation='relu')
    conv3 = tf.keras.layers.Conv1D(filters=32, kernel_size=4, activation='relu')
    lstm = tf.keras.layers.LSTM(32, activation='tanh')
    dense1 = tf.keras.layers.Dense(32, activation='relu')
    outputs = tf.keras.layers.Dense(seconds_out, activation='linear')
    layers = [inputs, conv1, conv2, conv3, lstm, dense1, outputs]
    # create model
    model = tf.keras.models.Sequential(layers)
    model.summary()
    # compile model
    opt = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer=opt, loss='mean_squared_error')
    return model

# %% [markdown]
# ## 4. Train Model

# %%
n_features = X_train.shape[2]
model =  cnn_lstm(seconds_in, seconds_out, n_features, lr=0.0001)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 17, 64)            2880
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 14, 32)            8224
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 11, 32)            4128
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                8320
# _________________________________________________________________
# dense (Dense)                (None, 32)                1056
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                660
# =================================================================
# Total params: 25,268
# Trainable params: 25,268
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                  min_delta=0.0001,
                                                  patience=20,
                                                  verbose=0,
                                                  mode='auto',
                                                  restore_best_weights=True)
history = model.fit(X_train,
                    y_train,
                    epochs=50,
                    batch_size=32,
                    validation_data=(X_test, y_test),
                    callbacks=[early_stopping],
                    verbose=1)
# Out:
# Epoch 1/50
# 1390/1390 [==============================] - 10s 7ms/step - loss: 0.0490 - val_loss: 0.0387
# Epoch 2/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0392 - val_loss: 0.0364
# Epoch 3/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0372 - val_loss: 0.0349
# Epoch 4/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0359 - val_loss: 0.0342
# Epoch 5/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0349 - val_loss: 0.0329
# Epoch 6/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0341 - val_loss: 0.0334
# Epoch 7/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0334 - val_loss: 0.0330
# Epoch 8/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0328 - val_loss: 0.0338
# Epoch 9/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0324 - val_loss: 0.0339
# Epoch 10/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0322 - val_loss: 0.0319
# Epoch 11/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0319 - val_loss: 0.0319
# Epoch 12/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0315 - val_loss: 0.0315
# Epoch 13/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0312 - val_loss: 0.0321
# Epoch 14/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0309 - val_loss: 0.0313
# Epoch 15/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0307 - val_loss: 0.0335
# Epoch 16/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0305 - val_loss: 0.0314
# Epoch 17/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0302 - val_loss: 0.0343
# Epoch 18/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0300 - val_loss: 0.0311
# Epoch 19/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0298 - val_loss: 0.0313
# Epoch 20/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0296 - val_loss: 0.0338
# Epoch 21/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0293 - val_loss: 0.0320
# Epoch 22/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0291 - val_loss: 0.0327
# Epoch 23/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0289 - val_loss: 0.0317
# Epoch 24/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0288 - val_loss: 0.0314
# Epoch 25/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0286 - val_loss: 0.0327
# Epoch 26/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0283 - val_loss: 0.0317
# Epoch 27/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0281 - val_loss: 0.0312
# Epoch 28/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0281 - val_loss: 0.0319
# Epoch 29/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0277 - val_loss: 0.0322
# Epoch 30/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0276 - val_loss: 0.0316
# Epoch 31/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0275 - val_loss: 0.0309
# Epoch 32/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0273 - val_loss: 0.0315
# Epoch 33/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0272 - val_loss: 0.0323
# Epoch 34/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0271 - val_loss: 0.0312
# Epoch 35/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0269 - val_loss: 0.0326
# Epoch 36/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0267 - val_loss: 0.0329
# Epoch 37/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0267 - val_loss: 0.0311
# Epoch 38/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0264 - val_loss: 0.0308
# Epoch 39/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0263 - val_loss: 0.0320
# Epoch 40/50
# 1390/1390 [==============================] - 9s 6ms/step - loss: 0.0262 - val_loss: 0.0335
# Epoch 41/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0261 - val_loss: 0.0315
# Epoch 42/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0260 - val_loss: 0.0332
# Epoch 43/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0258 - val_loss: 0.0320
# Epoch 44/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0256 - val_loss: 0.0314
# Epoch 45/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0255 - val_loss: 0.0332
# Epoch 46/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0254 - val_loss: 0.0320
# Epoch 47/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0253 - val_loss: 0.0320
# Epoch 48/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0251 - val_loss: 0.0319
# Epoch 49/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0251 - val_loss: 0.0321
# Epoch 50/50
# 1390/1390 [==============================] - 9s 7ms/step - loss: 0.0249 - val_loss: 0.0311

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
min_mse = min(val_loss)
print(f'Minimal Loss: {min_mse:.4f}')
print(f'RMSE: {np.sqrt(min_mse)*max_throughput:.1f}')
plt.figure(figsize=(5,5))
plt.plot(loss, 'r', label='Loss of training data')
plt.plot(val_loss, 'b-', label='Loss of validation data')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Training Epoch')
plt.legend()
plt.show()
# Out:
# Minimal Loss: 0.0308
# RMSE: 336.8

# %% [markdown]
# ## 5. Test-Predict Comparision

# %%
n = 100 # test example number
x_in = X_test[n].reshape(1, seconds_in, n_features)
y_true = y_test[n] # test true
y_pred = model.predict(x_in).flatten()
print(f'Example forecast MSE: {mean_squared_error(y_true, y_pred):.4f}')
plt.plot(y_true * max_throughput, 'b')
plt.plot(y_pred * max_throughput, 'r')
plt.ylim(0, max_throughput)
plt.show()
# Out:
# Example forecast MSE: 0.0100
