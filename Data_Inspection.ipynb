# %% [markdown]
# # Data Inspection

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.Load the dataset

# %%
df = pd.read_csv('Lumos5G-v1.0.csv')
df.head(5)
# Out:
#    run_num  seq_num  abstractSignalStr   latitude  longitude  movingSpeed  \
# 0        1      1.0                  2  44.975314 -93.259316     0.094889
# 1        1      2.0                  2  44.975311 -93.259311     0.876634
# 2        1      3.0                  2  44.975305 -93.259292     2.225798
# 3        1      4.0                  2  44.975293 -93.259258     3.180726
# 4        1      5.0                  2  44.975278 -93.259214     3.751234
#
#    compassDirection        nrStatus  lte_rssi  lte_rsrp  lte_rsrq  \
# 0               150  NOT_RESTRICTED     -61.0       -94     -14.0
# 1               117  NOT_RESTRICTED     -61.0       -94     -14.0
# 2               113  NOT_RESTRICTED     -61.0       -94     -14.0
# 3               114  NOT_RESTRICTED     -59.0       -95     -16.0
# 4               115  NOT_RESTRICTED     -59.0       -95     -16.0
#
#       lte_rssnr  nr_ssRsrp  nr_ssRsrq  nr_ssSinr  Throughput mobility_mode  \
# ...

# %%
df.tail(5)
# Out:
#        run_num  seq_num  abstractSignalStr   latitude  longitude  movingSpeed  \
# 68113      118    779.0                  1  44.975063 -93.259101     1.011944
# 68114      118    780.0                  1  44.975067 -93.259098     0.906543
# 68115      118    781.0                  1  44.975069 -93.259099     0.751355
# 68116      118    782.0                  1  44.975071 -93.259099     0.656095
# 68117      118    783.0                  1  44.975073 -93.259100     0.568798
#
#        compassDirection        nrStatus  lte_rssi  lte_rsrp  lte_rsrq  \
# 68113                42  NOT_RESTRICTED     -57.0       -91     -16.0
# 68114                42  NOT_RESTRICTED     -57.0       -91     -16.0
# 68115                41  NOT_RESTRICTED     -57.0       -91     -16.0
# 68116                39  NOT_RESTRICTED     -57.0       -91     -16.0
# 68117                38       CONNECTED     -57.0       -91     -16.0
#
#           lte_rssnr  nr_ssRsrp  nr_ssRsrq  nr_ssSinr  Throughput  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68118 entries, 0 to 68117
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   run_num               68118 non-null  int64
#  1   seq_num               68118 non-null  float64
#  2   abstractSignalStr     68118 non-null  int64
#  3   latitude              68118 non-null  float64
#  4   longitude             68118 non-null  float64
#  5   movingSpeed           68118 non-null  float64
#  6   compassDirection      68118 non-null  int64
#  7   nrStatus              68118 non-null  object
#  8   lte_rssi              65137 non-null  float64
#  9   lte_rsrp              68118 non-null  int64
#  10  lte_rsrq              65137 non-null  float64
#  11  lte_rssnr             65137 non-null  float64
#  12  nr_ssRsrp             51990 non-null  float64
#  13  nr_ssRsrq             51990 non-null  float64
# ...

# %% [markdown]
# ## 2. Plot Some Data

# %%
run = df.loc[(df['run_num']==1)]
run.head(3)
# Out:
#    run_num  seq_num  abstractSignalStr   latitude  longitude  movingSpeed  \
# 0        1      1.0                  2  44.975314 -93.259316     0.094889
# 1        1      2.0                  2  44.975311 -93.259311     0.876634
# 2        1      3.0                  2  44.975305 -93.259292     2.225798
#
#    compassDirection        nrStatus  lte_rssi  lte_rsrp  lte_rsrq  \
# 0               150  NOT_RESTRICTED     -61.0       -94     -14.0
# 1               117  NOT_RESTRICTED     -61.0       -94     -14.0
# 2               113  NOT_RESTRICTED     -61.0       -94     -14.0
#
#       lte_rssnr  nr_ssRsrp  nr_ssRsrq  nr_ssSinr  Throughput mobility_mode  \
# 0  2.147484e+09        NaN        NaN        NaN          78       driving
# 1  2.147484e+09        NaN        NaN        NaN         117       driving
# 2  2.147484e+09        NaN        NaN        NaN         110       driving
#
#   trajectory_direction  tower_id
# 0                   CW        16
# ...

# %%
run = df[["seq_num", "Throughput"]]
run.head()
# Out:
#    seq_num  Throughput
# 0      1.0          78
# 1      2.0         117
# 2      3.0         110
# 3      4.0         108
# 4      5.0         100

# %%
run_number = 88
run = df.loc[(df['run_num']==run_number)][["seq_num", "Throughput"]]
run=run.set_index("seq_num")
run.head(5)
# Out:
#          Throughput
# seq_num
# 1.0             113
# 2.0             100
# 3.0             153
# 4.0             355
# 5.0             479

# %%
run.plot(figsize=(10,5),x_compat=True,grid=True)

# %%
run['Throughput'].hist(bins=10)

# %%
df.head(10)
# Out:
#    run_num  seq_num  abstractSignalStr   latitude  longitude  movingSpeed  \
# 0        1      1.0                  2  44.975314 -93.259316     0.094889
# 1        1      2.0                  2  44.975311 -93.259311     0.876634
# 2        1      3.0                  2  44.975305 -93.259292     2.225798
# 3        1      4.0                  2  44.975293 -93.259258     3.180726
# 4        1      5.0                  2  44.975278 -93.259214     3.751234
# 5        1      6.0                  2  44.975259 -93.259166     4.083331
# 6        1      7.0                  2  44.975237 -93.259119     4.130768
# 7        1      8.0                  2  44.975211 -93.259078     4.107023
# 8        1      9.0                  2  44.975181 -93.259047     3.977770
# 9        1     10.0                  2  44.975147 -93.259035     3.679054
#
#    compassDirection        nrStatus  lte_rssi  lte_rsrp  lte_rsrq  \
# 0               150  NOT_RESTRICTED     -61.0       -94     -14.0
# ...

# %%
# set run_num and seq_num as indexes
ndf = df.set_index(['run_num', 'seq_num'])
ndf.head()
# Out:
#                  abstractSignalStr   latitude  longitude  movingSpeed  \
# run_num seq_num
# 1       1.0                      2  44.975314 -93.259316     0.094889
#         2.0                      2  44.975311 -93.259311     0.876634
#         3.0                      2  44.975305 -93.259292     2.225798
#         4.0                      2  44.975293 -93.259258     3.180726
#         5.0                      2  44.975278 -93.259214     3.751234
#
#                  compassDirection        nrStatus  lte_rssi  lte_rsrp  \
# run_num seq_num
# 1       1.0                   150  NOT_RESTRICTED     -61.0       -94
#         2.0                   117  NOT_RESTRICTED     -61.0       -94
#         3.0                   113  NOT_RESTRICTED     -61.0       -94
#         4.0                   114  NOT_RESTRICTED     -59.0       -95
#         5.0                   115  NOT_RESTRICTED     -59.0       -95
#
#                  lte_rsrq     lte_rssnr  nr_ssRsrp  nr_ssRsrq  nr_ssSinr  \
# ...

# %%
ndf.loc[50, 110]
# Out:
# abstractSignalStr                 4
# latitude                    44.9741
# longitude                  -93.2601
# movingSpeed                 1.28129
# compassDirection                216
# nrStatus                  CONNECTED
# lte_rssi                        -55
# lte_rsrp                        -83
# lte_rsrq                        -10
# lte_rssnr               2.14748e+09
# nr_ssRsrp                       -87
# nr_ssRsrq                       -12
# nr_ssSinr                        15
# Throughput                      301
# mobility_mode               walking
# trajectory_direction             CW
# tower_id                         24
# Name: (50, 110.0), dtype: object
